# %% [markdown]
# #**Install**

# %%
# !pip install bertopic
# !pip install bertopic[visualization]
# !pip install tweet-preprocessor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bertopic
#   Downloading bertopic-0.12.0-py2.py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 10.2 MB/s
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.8/dist-packages (from bertopic) (1.0.2)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.8/dist-packages (from bertopic) (1.21.6)
# Collecting sentence-transformers>=0.4.1
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      |████████████████████████████████| 85 kB 6.7 MB/s
# Collecting hdbscan>=0.8.28
#   Downloading hdbscan-0.8.29.tar.gz (5.2 MB)
#      |████████████████████████████████| 5.2 MB 52.8 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting pyyaml<6.0
#   Downloading PyYAML-5.4.1-cp38-cp38-manylinux1_x86_64.whl (662 kB)
#      |████████████████████████████████| 662 kB 72.3 MB/s
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.8/dist-packages (from bertopic) (1.3.5)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.8/dist-packages (from bertopic) (5.5.0)
# Collecting umap-learn>=0.5.0
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      |████████████████████████████████| 88 kB 10.2 MB/s
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.8/dist-packages (from bertopic) (4.64.1)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.8/dist-packages (from hdbscan>=0.8.28->bertopic) (1.7.3)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.8/dist-packages (from hdbscan>=0.8.28->bertopic) (1.2.0)
# Requirement already satisfied: cython>=0.27 in /usr/local/lib/python3.8/dist-packages (from hdbscan>=0.8.28->bertopic) (0.29.32)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.1.5->bertopic) (2022.6)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from plotly>=4.7.0->bertopic) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from plotly>=4.7.0->bertopic) (8.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.1.0)
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.25.1-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 59.5 MB/s
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from sentence-transformers>=0.4.1->bertopic) (1.13.0+cu116)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.8/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.14.0+cu116)
# Requirement already satisfied: nltk in /usr/local/lib/python3.8/dist-packages (from sentence-transformers>=0.4.1->bertopic) (3.7)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 56.7 MB/s
# Collecting huggingface-hub>=0.4.0
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 78.0 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.8.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (4.4.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.0.9)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2022.6.2)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 62.2 MB/s
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.8/dist-packages (from umap-learn>=0.5.0->bertopic) (0.56.4)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.8.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 61.3 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (57.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.8/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (5.1.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.8/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (0.39.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata->numba>=0.49->umap-learn>=0.5.0->bertopic) (3.11.0)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk->sentence-transformers>=0.4.1->bertopic) (7.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (1.24.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.8/dist-packages (from torchvision->sentence-transformers>=0.4.1->bertopic) (7.1.2)
# Building wheels for collected packages: hdbscan, sentence-transformers, umap-learn, pynndescent
#   Building wheel for hdbscan (PEP 517) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.29-cp38-cp38-linux_x86_64.whl size=2700851 sha256=284d73abfc7bd0afa982e57c96c4dec73fe2cdf1b11668cc3ac3e24bb635dddd
#   Stored in directory: /root/.cache/pip/wheels/76/06/48/527e038689c581cc9e519c73840efdc7473805149e55bd7ffd
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=b06bd7377052ace084c3f449f629193a519153c8fc3c43798d323791f680efbc
#   Stored in directory: /root/.cache/pip/wheels/5e/6f/8c/d88aec621f3f542d26fac0342bef5e693335d125f4e54aeffe
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82829 sha256=780f6533e88e7d6984d034025230a45bce8171f1f5d02860752ec27895fcc584
#   Stored in directory: /root/.cache/pip/wheels/a9/3a/67/06a8950e053725912e6a8c42c4a3a241410f6487b8402542ea
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.8-py3-none-any.whl size=55513 sha256=93329dff7d4d7bd78b48ddc0fd65c63ea18e185988e05533a0717760f4a17de3
#   Stored in directory: /root/.cache/pip/wheels/1c/63/3a/29954bca1a27ba100ed8c27973a78cb71b43dc67aed62e80c3
# Successfully built hdbscan sentence-transformers umap-learn pynndescent
# Installing collected packages: pyyaml, tokenizers, huggingface-hub, transformers, sentencepiece, pynndescent, umap-learn, sentence-transformers, hdbscan, bertopic
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
# Successfully installed bertopic-0.12.0 hdbscan-0.8.29 huggingface-hub-0.11.1 pynndescent-0.5.8 pyyaml-5.4.1 sentence-transformers-2.2.2 sentencepiece-0.1.97 tokenizers-0.13.2 transformers-4.25.1 umap-learn-0.5.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: bertopic[visualization] in /usr/local/lib/python3.8/dist-packages (0.12.0)
# WARNING: bertopic 0.12.0 does not provide the extra 'visualization'
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.8/dist-packages (from bertopic[visualization]) (4.64.1)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.8/dist-packages (from bertopic[visualization]) (1.3.5)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from bertopic[visualization]) (2.2.2)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.8/dist-packages (from bertopic[visualization]) (1.21.6)
# Requirement already satisfied: pyyaml<6.0 in /usr/local/lib/python3.8/dist-packages (from bertopic[visualization]) (5.4.1)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.8/dist-packages (from bertopic[visualization]) (5.5.0)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.8/dist-packages (from bertopic[visualization]) (1.0.2)
# Requirement already satisfied: umap-learn>=0.5.0 in /usr/local/lib/python3.8/dist-packages (from bertopic[visualization]) (0.5.3)
# Requirement already satisfied: hdbscan>=0.8.28 in /usr/local/lib/python3.8/dist-packages (from bertopic[visualization]) (0.8.29)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.8/dist-packages (from hdbscan>=0.8.28->bertopic[visualization]) (1.7.3)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.8/dist-packages (from hdbscan>=0.8.28->bertopic[visualization]) (1.2.0)
# Requirement already satisfied: cython>=0.27 in /usr/local/lib/python3.8/dist-packages (from hdbscan>=0.8.28->bertopic[visualization]) (0.29.32)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.1.5->bertopic[visualization]) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.1.5->bertopic[visualization]) (2022.6)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from plotly>=4.7.0->bertopic[visualization]) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from plotly>=4.7.0->bertopic[visualization]) (8.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.22.2.post1->bertopic[visualization]) (3.1.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.8/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (3.7)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.8/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (0.1.97)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.8/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (4.25.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.8/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (0.14.0+cu116)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (1.13.0+cu116)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (0.11.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2.23.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (21.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (4.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.8.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.0.9)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2022.6.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.8/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (0.13.2)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.8/dist-packages (from umap-learn>=0.5.0->bertopic[visualization]) (0.56.4)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.8/dist-packages (from umap-learn>=0.5.0->bertopic[visualization]) (0.5.8)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.8/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic[visualization]) (5.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic[visualization]) (57.4.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.8/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic[visualization]) (0.39.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata->numba>=0.49->umap-learn>=0.5.0->bertopic[visualization]) (3.11.0)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk->sentence-transformers>=0.4.1->bertopic[visualization]) (7.1.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.0.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.8/dist-packages (from torchvision->sentence-transformers>=0.4.1->bertopic[visualization]) (7.1.2)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tweet-preprocessor
#   Downloading tweet_preprocessor-0.6.0-py3-none-any.whl (27 kB)
# Installing collected packages: tweet-preprocessor
# Successfully installed tweet-preprocessor-0.6.0

# %% [markdown]
# #**Import**

# %%
# Data processing
import re
import numpy as np
import pandas as pd
from datetime import datetime

# Tweet preprocessor
import preprocessor as p

# Count vectorization
from sklearn.feature_extraction.text import CountVectorizer

# Dimension reduction
from umap import UMAP
from sklearn.decomposition import PCA

# Clustering
from hdbscan import HDBSCAN
from sklearn.cluster import KMeans

# BERTopic
from bertopic import BERTopic

# Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #**Data**

# %% [markdown]
# ###**Import dataset**

# %%
migr_twit = pd.read_csv('/content/drive/MyDrive/MA Computational Linguistics/UK-R-migr-RA-twit-all.csv')

# %% [markdown]
# ###**Data exploratory**

# %%
migr_twit.shape
# Out:
# (6472, 6)

# %%
pd.set_option('display.max_colwidth', 100)
migr_twit.head()
# Out:
#                    id  \
# 0  153810782696640512
# 1  153811659780141057
# 2  156709735557644288
# 3  156742504908210176
# 4  158972986379087872
#
#                                                                                                  tweet  \
# 0  Of course we'll miss our immigration targets: we have a government which doesn't want control of...
# 1                                      @liontornado Subordinate to the EU immigration laws, of course.
# 2  Unlimited immigration is costing British people jobs. Controlling non-EU immigration is merely c...
# 3  Patriotic Labour voters who have had enough of Miliband's spiel and want a Party that will contr...
# 4  RT @poljourno: UK's immigration system 'benefits no one'. By @Goddersukip - @GawainTowler @Nigel...
#
#                   date       username      party        type
# 0  2012-01-02 12:12:02  @Nigel_Farage  far-right       tweet
# 1  2012-01-02 12:15:32  @Nigel_Farage  far-right  replied_to
# 2  2012-01-10 12:11:27          @UKIP  far-right       tweet
# 3  2012-01-10 14:21:39          @UKIP  far-right       tweet
# 4  2012-01-16 18:04:48          @UKIP  far-right   retweeted

# %%
migr_twit['party'].value_counts()
# Out:
# far-right     5034
# right-wing    1438
# Name: party, dtype: int64

# %% [markdown]
# #**Corpus linguistics**

# %%
# Remove duplicates (?)
# migr_twit = migr_twit.drop_duplicates()

# Remove retweets (?)
# migr_twit = migr_twit.loc[(migr_twit.type == "retweet"), :]

# %% [markdown]
# #**Hyperparameters**

# %% [markdown]
# ###**Dimension reduction**

# %%
# Initiate UMAP
# umap_model = UMAP(n_neighbors=15, n_components=5, min_dist=0.0, metric='cosine', random_state=100)

# %% [markdown]
# ###**Clustering**

# %%
# Initiate HDBSCAN
# hdbscan_model = HDBSCAN(min_cluster_size=10, min_samples = 10,metric='euclidean', prediction_data=True)

# %% [markdown]
# ###**Count vectorizer**

# %%
# Use CountVectorizer to remove stopwords and set ngram range
vectorizer_model_1 = CountVectorizer(stop_words="english", ngram_range=(1, 2))
vectorizer_model_2 = CountVectorizer(stop_words="english", ngram_range=(1, 3))

# %% [markdown]
# #**Pre-processing**

# %%
# Keep only some columns
migr_text = migr_twit.filter(['username','tweet', 'date', 'party'], axis=1)

# %%
# Customizing the preprocessor to exclude removing hashtags since they are valuable as a rich information
p.set_options(p.OPT.URL, p.OPT.EMOJI,p.OPT.MENTION,p.OPT.SMILEY,p.OPT.NUMBER)

# Forming a separate feature for cleaned tweets
for i,v in enumerate(migr_text['tweet']):
  migr_text.loc[i,'text'] = p.clean(v)
    
migr_text.head()
# Out:
#         username  \
# 0  @Nigel_Farage
# 1  @Nigel_Farage
# 2          @UKIP
# 3          @UKIP
# 4          @UKIP
#
#                                                                                                  tweet  \
# 0  Of course we'll miss our immigration targets: we have a government which doesn't want control of...
# 1                                      @liontornado Subordinate to the EU immigration laws, of course.
# 2  Unlimited immigration is costing British people jobs. Controlling non-EU immigration is merely c...
# 3  Patriotic Labour voters who have had enough of Miliband's spiel and want a Party that will contr...
# 4  RT @poljourno: UK's immigration system 'benefits no one'. By @Goddersukip - @GawainTowler @Nigel...
#
#                   date      party  \
# 0  2012-01-02 12:12:02  far-right
# 1  2012-01-02 12:15:32  far-right
# 2  2012-01-10 12:11:27  far-right
# 3  2012-01-10 14:21:39  far-right
# 4  2012-01-16 18:04:48  far-right
#
#                                                                                                   text
# 0  Of course we'll miss our immigration targets: we have a government which doesn't want control of...
# 1                                                   Subordinate to the EU immigration laws, of course.
# 2  Unlimited immigration is costing British people jobs. Controlling non-EU immigration is merely c...
# 3  Patriotic Labour voters who have had enough of Miliband's spiel and want a Party that will contr...
# 4                                                 RT : UK's immigration system 'benefits no one'. By -

# %%
# Remove only the '#' not the word after
def remove_hashtag_sign(text):
  text = re.sub(r'#', '', text)
  return text

migr_text['text'] = migr_text['text'].apply(lambda x:remove_hashtag_sign(x))

# %%
# Remove extra white spaces, punctuation and apply lower casing
migr_text['text'] = migr_text['text'].str.lower().str.replace('[^\w\s]',' ').str.replace('\s\s+', ' ')
migr_text.head()
# Out:
#         username  \
# 0  @Nigel_Farage
# 1  @Nigel_Farage
# 2          @UKIP
# 3          @UKIP
# 4          @UKIP
#
#                                                                                                  tweet  \
# 0  Of course we'll miss our immigration targets: we have a government which doesn't want control of...
# 1                                      @liontornado Subordinate to the EU immigration laws, of course.
# 2  Unlimited immigration is costing British people jobs. Controlling non-EU immigration is merely c...
# 3  Patriotic Labour voters who have had enough of Miliband's spiel and want a Party that will contr...
# 4  RT @poljourno: UK's immigration system 'benefits no one'. By @Goddersukip - @GawainTowler @Nigel...
#
#                   date      party  \
# 0  2012-01-02 12:12:02  far-right
# 1  2012-01-02 12:15:32  far-right
# 2  2012-01-10 12:11:27  far-right
# 3  2012-01-10 14:21:39  far-right
# 4  2012-01-16 18:04:48  far-right
#
#                                                                                                   text
# 0  of course we ll miss our immigration targets we have a government which doesn t want control of ...
# 1                                                    subordinate to the eu immigration laws of course
# 2  unlimited immigration is costing british people jobs controlling non eu immigration is merely co...
# 3  patriotic labour voters who have had enough of miliband s spiel and want a party that will contr...
# 4                                                       rt uk s immigration system benefits no one by

# %% [markdown]
# #**BERTopic**

# %% [markdown]
# ###**Training**

# %%
# Prepare tweet list
tweet_list = migr_text.text.tolist()
# Prepare date list which will be useful later for building the Dynamic Topic Modeling (DTM)
timestamps = migr_text.date.tolist()
# Prepare the party & username lists which will be useful later for building the Topics per class
tweet_party = migr_text.party.tolist()
tweet_username = migr_text.username.tolist()

# Initialize the Sentence model (1)
# topic_model_1 = BERTopic(embedding_model="all-MiniLM-L6-v2", low_memory=True, calculate_probabilities=True,verbose=True)
# Initialize the BERTweet model (2)
# topic_model_2 = BERTopic(embedding_model="vinai/bertweet-base", low_memory=True, calculate_probabilities=True,verbose=True)

# Train model 1
# topics_1, probs_1 = topic_model_1.fit_transform(tweet_list)
# Train model 2
# topics_2, probs_2 = topic_model_2.fit_transform(tweet_list)

# %%
# Get topic frequencies for model 1
# topic_model_1.get_topic_freq()

# %%
# Get topic frequencies for model 2
# topic_model_2.get_topic_freq()

# %%
# Get topic information for model 1
# topic_model_1.get_topic_info().head(21)

# %%
# Get topic information for model 2
# topic_model_2.get_topic_info().head(21)

# %%
# Save the Sentence Transformers model
# topic_model_1.save('/content/drive/MyDrive/MA Computational Linguistics/Sentence_Transformers')

# %%
# Save the BERTweet model
# topic_model_2.save('/content/drive/MyDrive/MA Computational Linguistics/BERTweets')

# %% [markdown]
# ###**Load baseline model**

# %%
# Load the baseline topic model
# migr_tmodel = BERTopic.load('/content/drive/MyDrive/MA Computational Linguistics/Sentence_Transformers')

# %% [markdown]
# **Comment**: eventually, the Sentence Transformers model was chosen for the optimization step as it generated better results (i.e., more coherent topics) than the BERTweets model.

# %% [markdown]
# ###**Optimization**

# %% [markdown]
# ***Constant parameters***
#
# *   Language set to *English* (language by defualt)
# *   Dimension reduction set to *UMAP* (algorithm by default)
# *   Clustering set to *HDBSCAN* (algorithm by default)
# *   Embedding model set to *Sentence Transformers* (embedding model by default)
# *   Low memory set to *True* to make sure less memory is used
# *   Calculate probabilities set to *Yes* to calculate the probabilities of topics found in a document
# *   Verbose set to *True* so that the model initiation process does not show messages
#
# ***Variable parameters***
#
# 1.   Count Vectorizer: [vectorizer_model_1; **vectorizer_model_2**]
# 2.   Top number of words: [10 (default number); **12**; 14]
# 3.   Topic diversity: [**0.2**; 0.4]
# 4.   Minimum topic size: [**10** (default number); 15; 20]
# 6.   Number of topics: [**40**; 50]

# %% [markdown]
# ####**1) Count vectorizer**

# %%
# Vectorizer model 1 (stopwords + ngram range set to (1,2))
# migr_tmodel.update_topics(tweet_list, vectorizer_model=vectorizer_model_1)

# %%
# Get topic info
# migr_tmodel.get_topic_info()

# %%
# Get topic info for the first 10 topics
# migr_tmodel.get_topic_info().head(11)

# %%
# Vectorizer model 2 (stopwords + ngram range set to (1,3))
# migr_tmodel.update_topics(tweet_list, vectorizer_model=vectorizer_model_2)

# %%
# Get topic info
# migr_tmodel.get_topic_info()

# %%
# Get topic info for the first 10 topics
# migr_tmodel.get_topic_info().head(11)

# %% [markdown]
# **Comment**: not much difference in terms of topics was found in the results when choosing one Count vectorizer or another. However, the second model seemed to us better than the second for at least two reasons. First, we felt that in most cases the n-gram range set to (1, 3) provided us with better information (e.g., topic 27, 1st vs 2nd model: *ukip immigration policy* is more accurate than *ukip* & *immigration policy*; or, topic 49, in the 2nd model: *labour immigration pledge* highlighs where the pledge comes from). Second, the first model appeared to be exaggeratedly skewed towards the first topic (EU), probably because the model was not able to detect the different topics covered when talking about immigration within the EU context. Finally, at this stage of the optimization, the number of words defining a topic is set to 10. The results are quite satisfactory in terms of topic coherence but let's see what happens when incrementing this number. In fact, it is recommended to keep this value below 30 and preferably between 10 and 20, but never below 10.

# %%
# We are satisfied with the results generated by the last model
# We then initialize a new model (3)
# topic_model_3 = BERTopic(embedding_model="all-MiniLM-L6-v2", low_memory=True, calculate_probabilities=True, verbose=True, vectorizer_model=vectorizer_model_2)

# Train model 3
# topics_3, probs_3 = topic_model_3.fit_transform(tweet_list)

# %%
# Save the Updated Sentence Transformers model
# topic_model_3.save('/content/drive/MyDrive/MA Computational Linguistics/ST_CV2_10')

# %% [markdown]
# ####**2) Top number of words**

# %%
# Initialize new model (4) with the top 12 words
# topic_model_4 = BERTopic(embedding_model="all-MiniLM-L6-v2", low_memory=True, calculate_probabilities=True, verbose=True, vectorizer_model=vectorizer_model_2, top_n_words=12)

# Train model 4
# topics_4, probs_4 = topic_model_4.fit_transform(tweet_list)

# %%
# Get topic frequencies for model 4
# topic_model_4.get_topic_freq()

# %%
# Get topic information for model 4
# topic_model_4.get_topic_info().head(21)

# %% [markdown]
# **Comment**: incrementing the number of words up to 14 resulted in major number of topics and word intrusions within them. However, choosing the 12 top words allowed us to eliminate some outliers that were found in the previous model with the relevant parameter set to 10.
# Next, we will test whether diversifing or not the topic diversity (i.e. by limiting the number of duplicate words in each topic) can further improve our BERT model.

# %%
# Save the Updated Sentence Transformers model
# topic_model_4.save('/content/drive/MyDrive/MA Computational Linguistics/ST_CV2_12_None')

# %% [markdown]
# ####**3) Topic diversity**

# %%
# Initialize new model (5) with topic diversity set to 0.2
# topic_model_5 = BERTopic(embedding_model="all-MiniLM-L6-v2", low_memory=True, calculate_probabilities=True, verbose=True, vectorizer_model=vectorizer_model_2, top_n_words=12, diversity=0.2)

# Train model 5
# topics_5, probs_5 = topic_model_5.fit_transform(tweet_list)

# %%
# Get topic frequencies for model 5
# topic_model_5.get_topic_freq()

# %%
# Get topic information for model 5
# topic_model_5.get_topic_info().head(21)

# %% [markdown]
# **Comment**: in a scale between 0 (not at all diverse) and 1 (very diverse), incrementing the topic diversity up to 0.4 had the result to rise the number of topics while not always giving coherent information within topics. However, we found 0.2 as the perfect value providing a much more diversified topic representation while also keeping the same number of topics as in the previous model.

# %%
# Save the Updated Sentence Transformers model
# topic_model_5.save('/content/drive/MyDrive/MA Computational Linguistics/ST_CV2_12_0.2_10')

# %% [markdown]
# ####**4) Minimum topic size**

# %%
# Initialize new model (6) with topic size set to 15
# topic_model_6 = BERTopic(embedding_model="all-MiniLM-L6-v2", low_memory=True, calculate_probabilities=True, verbose=True, vectorizer_model=vectorizer_model_2, top_n_words=12, diversity=0.2, min_topic_size=15)

# Train model 6
# topics_6, probs_6 = topic_model_6.fit_transform(tweet_list)

# %%
# Get topic frequencies for model 6
# topic_model_6.get_topic_freq()

# %%
# Get topic information for model 6
# topic_model_6.get_topic_info().head(51)

# %% [markdown]
# **Comment**: many of the clusters of 15 documents, or less, were either repetitive or too specific so we decided to reduce the minimum topic size to 15. However, since we want to reduce the topic dimension to 30-50 topics, only the clusters with 30 documents or more will be considered, so we do not care too much about this parameter and we left it to 10.`

# %%
# Save the Updated Sentence Transformers model
# topic_model_6.save('/content/drive/MyDrive/MA Computational Linguistics/ST_CV2_12_0.2_15_No')

# %% [markdown]
# ####**5) Number of topics**

# %%
# Initialize final model with 40 topics
# topic_model_fn = BERTopic(embedding_model="all-MiniLM-L6-v2", low_memory=True, calculate_probabilities=True, verbose=True, vectorizer_model=vectorizer_model_2, top_n_words=12, diversity=0.2, min_topic_size=10, nr_topics=50)

# Train final model 
# topics_fn, probs_fn = topic_model_fn.fit_transform(tweet_list)

# %%
# Get topic frequencies for the final model
# topic_model_fn.get_topic_freq().head(11)

# %%
# Get topic information for the final model
# topic_model_fn.get_topic_info()

# %%
# Intertopic distance map
# topic_model_fn.visualize_topics(width=1000, height=1000)

# %% [markdown]
# **Comment**: when picking only 40 topics, the clusters get more defined so we decided to confirm this number and update our final model.
# After training many models (*a*-to-*f* models), we have almost always detected the same 12/13 topic categories or discussions around:
# - *Cameron's migration pledge*
# - *Issues related with immigration*
# - *UK Asylum system*
# - *Arrivals by boats*
# - *Refugee crisis*
# - *UKIP's political campaign*
# - *Brexit debate
# - *Control immigration*
# - *EU immigration*
# - *Points based immigration system*
# - *Welsh nation of sanctuary*
# - *UK-Rwanda Migration and Economic Development Partnership*

# %%
# Save the final model
# topic_model_fn.save('/content/drive/MyDrive/MA Computational Linguistics/ST_CV2_12_0.2_10_50')

# %% [markdown]
# ####**Further improvements**
#
# *   Count Vectorizer: customize other hyperparameters such as *min_df* and *max_features*
# *   Dimension reduction: try *PCA* instead of *UMAP*
# *   Clustering: try *Kmeans* instead of *HDBSCAN*

# %% [markdown]
# ###**Visualization**

# %%
# Load the final model
# migr_topic_model = BERTopic.load('/content/drive/MyDrive/MA Computational Linguistics/ST_CV2_12_0.2_10_40_finalb')

# %%
# Get topic information for the final model
# migr_topic_model.get_topic_info()

# %%
# Intertopic distance map
# migr_topic_model.visualize_topics(width=750, height=750)

# %%
# Barchart
# migr_topic_model.visualize_barchart([27], n_words=8, width=300, height=300, custom_labels=False)

# %% [markdown]
# **Comment**: with the support of visualization we try to get a clearer sense of the topics extracted, refine the macro categories identified in the last optimization step by grouping up the topics within them. This work will be then useful for the labeling process.
# Here below are the final macro categories:
# 1. *Cameron's migration policy* {7: "David Cameron"; 26: "Net migration"}
# 2. *Housing crisis* {1: "Housing crisis"}
# 3. *Population growth* {19: "Population growth"}
# 4. *Tories' migration policy* {8: "Tories"; 11: "Boris Johnson's government"; 33 "UKIP's election campaign"}
# 5. *Migrant crisis* {30: "Migrant crisis"; 32: "Terrorism"; 31: "Economic migrants"}
# 6. *Arrivals by boat* {12: "Calais"; 39: "Dover"; 28: "Smuggling"; 24: "Channel crossing"; 27: "Migrant boats"}
# 7. *EU immigration* {18: "Romanian and Bulgarian migration"; 29: "EU-Turkey relations"; 37: "Common EU asylum system"; 15: "EU migration statistics"}
# 8. *UKIP's propaganda* {16: "Migration figures"; 17: "UKIP's interventions", 38: "TV and radio appearences", 34: "Biased BBC"}
# 9. *Immigration issues* {13: "Immigration scale"; 35: "Migrant benefits"; 25: "Welsh Nation of Sanctuary"; 22: "Health service"}
# 10. *Labour's migration responsability* {20: "Labour's responsability"}
# 11. *Workers' low wages* {23: "Workers' low wages"}
# 12. *Pro-Brexit campaign* {4: "Nigel Farage's campaign"; 6: "Australian points-based system"; 10: "Control immigration"; 36:"UKIP's immigration policy"}
# 13. *Illegal migration* {2: "Syrian refugee crisis"; 3: "New immigration plan"; 9: "UK-Rwanda Migration and Economic Development Partnership"; 5: "About UK-France cooperation"}
# 14. *Points based immigration system* {0: "Points-Based System"; 21: "New immigration system"}
# 15. *About Home Office* {14: "About Home Office"}

# %%
# Documents
# migr_topic_model.visualize_documents(tweet_list, width=3000, height=3000)

# %%
# Find topics
# migr_topic_model.find_topics("brexit", top_n=10)

# %% [markdown]
# ###**Labeling**

# %%
# Load the final model
migr_topic_model = BERTopic.load('/content/drive/MyDrive/MA Computational Linguistics/ST_CV2_12_0.2_10_40_finalb')

# %%
# Set topic labels
migr_topic_model.set_topic_labels({0: "points-based immigration system", 1: "housing crisis", 2: "syrian refugee crisis", 3: "new immigration plan", 4: "nigel farage's campaign", 5: "about uk-france cooperation", 6: "australian points-based system", 7: "david cameron's migration policy", 8: "tories", 9: "uk-rwanda partnership", 10: "control immigration", 11: "boris johnson's government", 12: "calais", 13: "immigration scale", 14: "about home office", 15: "eu migration statistics", 16: "migration figures", 17: "ukip's interventions", 18: "romanian and bulgarian migration", 19: "population growth", 20: "labour's responsability", 21: "new immigration system", 22: "health service", 23: "workers' low wages", 24: "channel crossing", 25: "welsh nation of sanctuary", 26: "net migration", 27: "migrant boats", 28: "smuggling", 29: "eu-turkey relations", 30: "migrant crisis", 31: "economic migrants", 32: "terrorism", 33: "ukip's election campaign", 34: "biased bbc", 35: "migrant benefits", 36:"ukip's immigration policy", 37: "common eu asylum system", 38: "tv and radio appearences", 39: "dover"})
migr_topic_model.get_topic_info().head(31)
# Out:
#     Topic  Count  \
# 0      -1   3622
# 1       0    153
# 2       1    148
# 3       2    143
# 4       3    141
# 5       4    126
# 6       5    126
# 7       6    114
# 8       7    100
# 9       8     92
# 10      9     88
# 11     10     87
# 12     11     81
# 13     12     79
# 14     13     77
# 15     14     75
# 16     15     74
# 17     16     66
# 18     17     65
# 19     18     59
# 20     19     54
# 21     20     53
# 22     21     53
# 23     22     52
# 24     23     51
# 25     24     50
# 26     25     50
# 27     26     48
# 28     27     47
# 29     28     47
# 30     29     46
#
#                                                                                            Name  \
# 0                                                        -1_immigration_ukip_migration_migrants
# 1                              0_points based immigration_based immigration_points based_points
# 2                                                  1_housing_housing crisis_immigration_mayoral
# 3                                 2_refugees_syrian refugees_refugee_vulnerable syrian refugees
# 4                             3_asylum_genuine need_nnewplanforimmigration_new plan immigration
# 5                                     4_farage_nigel farage_rt nigel farage_leader nigel farage
# 6                                  5_illegal migration_interior minister_french_french interior
# 7            6_australian style points_style points based_points based_points based immigration
# 8                                            7_david cameron_net migration_migration_mr cameron
# 9                                                           8_tories_tory_immigration_rt tories
# 10                                   9_rwanda_uk rwanda_migrants_migration economic development
# 11                            10_control immigration_leave eu_eu control_eu control immigration
# 12                                      11_priti patel_boris johnson_illegal immigrants_amnesty
# 13                                                  12_calais_migrants_calais migrant_calais rt
# 14                               13_immigration_debate immigration_immigration rt_scared debate
# 15                                    14_home secretary_secretary_theresa_immigration detention
# 16                                              15_eu migration_eu migrant_eu migrants_migrants
# 17                          16_ukip_ukip migration spokesman_ukip migration_migration spokesman
# 18         17_migration spokesman_ukip migration_ukip migration spokesman_immigration spokesman
# 19  18_romania bulgaria_bulgarian immigration_bulgarian romanian_romanian bulgarian immigration
# 20                                            19_population_growth_population growth_birmingham
# 21                                                       20_labour_party_labour party_rt labour
# 22                          21_immigration minister_minister_minister mark harper_minister mark
# 23                                        22_nhs_health service_health insurance_health tourism
# 24                                                       23_wages_wage_bank england_immigration
# 25                24_migrants crossed_crossed channel_crossing channel_migrants crossed channel
# 26                                                         25_wales_nation sanctuary_welsh_ukip
# 27                                 26_net migration_migration_net migration year_migration year
# 28                                                            27_boats_boat_migrants_reached uk
# 29                            28_smuggling_immigration enforcement_people smuggling_migrants uk
# 30                                                 29_turkey_turkish_visa free access_turkey eu
#
#                                 CustomName
# 0   -1_immigration_ukip_migration_migrants
# 1          points-based immigration system
# 2                           housing crisis
# 3                    syrian refugee crisis
# 4                     new immigration plan
# 5                  nigel farage's campaign
# 6              about uk-france cooperation
# 7           australian points-based system
# 8         david cameron's migration policy
# 9                                   tories
# 10                   uk-rwanda partnership
# 11                     control immigration
# 12              boris johnson's government
# 13                                  calais
# 14                       immigration scale
# 15                       about home office
# 16                 eu migration statistics
# 17                       migration figures
# 18                    ukip's interventions
# 19        romanian and bulgarian migration
# 20                       population growth
# 21                 labour's responsability
# 22                  new immigration system
# 23                          health service
# 24                      workers' low wages
# 25                        channel crossing
# 26               welsh nation of sanctuary
# 27                           net migration
# 28                           migrant boats
# 29                               smuggling
# 30                     eu-turkey relations

# %%
# Access customised labels
# migr_topic_model.custom_labels_

# %%
# Barchart
# migr_topic_model.visualize_barchart(top_n_topics=4, n_words=12, width=350, height=350, custom_labels=migr_topic_model.custom_labels_)

# %%
# Documents
# migr_topic_model.visualize_documents(tweet_list, width=3000, height=3000, custom_labels=migr_topic_model.custom_labels_)

# %% [markdown]
# ###**Merge topics**

# %%
# Create macro categories by merging topics
topics_to_merge = [[7, 26], [8, 11, 33], [30, 31, 32], [12, 24, 27, 28, 39], [15, 18, 29, 37], [16, 17, 34, 38], [13, 22, 25, 35], [4, 6, 10, 36], [2, 3, 5, 9], [0, 21]]
migr_topic_model.merge_topics(tweet_list, topics_to_merge)

# %%
# Get topic information for the final model
migr_topic_model.get_topic_info()
# Out:
#     Topic  Count  \
# 0      -1   3622
# 1       0    498
# 2       1    365
# 3       2    260
# 4       3    219
# 5       4    217
# 6       5    215
# 7       6    210
# 8       7    206
# 9       8    148
# 10      9    148
# 11     10    131
# 12     11     75
# 13     12     54
# 14     13     53
# 15     14     51
#
#                                                                      Name
# 0                                  -1_immigration_ukip_migration_migrants
# 1                                      0_asylum_rwanda_migration_refugees
# 2                  1_farage_australian style_australian style points_ukip
# 3                                           2_migrants_calais_dover_boats
# 4                                            3_immigration_wales_nhs_ukip
# 5                                         4_eu_bulgarian_romania_bulgaria
# 6                                5_tories_boris_priti patel_boris johnson
# 7      6_ukip_migration spokesman_ukip migration_ukip migration spokesman
# 8   7_based immigration_points based immigration_immigration_points based
# 9                             8_housing_housing crisis_immigration_crisis
# 10                    9_net migration_migration_david cameron_immigration
# 11                                 10_migrant crisis_crisis_refugees_isis
# 12                        11_home secretary_secretary_theresa_immigration
# 13                     12_population_growth_population growth_immigration
# 14                           13_labour_immigration_rt labour_labour party
# 15                                 14_wages_wage_immigration_bank england

# %% [markdown]
# **Comment**: now that we have obtained our macro catageries, we can rename them again:

# %%
# Set topic labels
migr_topic_model.set_topic_labels({0: "illegal migration", 1: "pro-brexit campaign", 2: "arrivals by boat", 3: "immigration issues", 4: "eu immigration", 5: "tories' migration policy", 6: "ukip's propaganda", 7: "points based immigration system", 8: "housing crisis", 9: "cameron's migration policy", 10: "migrant crisis", 11: "about home office", 12: "population growth", 13: "labour's migration responsability", 14: "workers' low wages"})
migr_topic_model.get_topic_info()
# Out:
#     Topic  Count  \
# 0      -1   3622
# 1       0    498
# 2       1    365
# 3       2    260
# 4       3    219
# 5       4    217
# 6       5    215
# 7       6    210
# 8       7    206
# 9       8    148
# 10      9    148
# 11     10    131
# 12     11     75
# 13     12     54
# 14     13     53
# 15     14     51
#
#                                                                      Name  \
# 0                                  -1_immigration_ukip_migration_migrants
# 1                                      0_asylum_rwanda_migration_refugees
# 2                  1_farage_australian style_australian style points_ukip
# 3                                           2_migrants_calais_dover_boats
# 4                                            3_immigration_wales_nhs_ukip
# 5                                         4_eu_bulgarian_romania_bulgaria
# 6                                5_tories_boris_priti patel_boris johnson
# 7      6_ukip_migration spokesman_ukip migration_ukip migration spokesman
# 8   7_based immigration_points based immigration_immigration_points based
# 9                             8_housing_housing crisis_immigration_crisis
# 10                    9_net migration_migration_david cameron_immigration
# 11                                 10_migrant crisis_crisis_refugees_isis
# 12                        11_home secretary_secretary_theresa_immigration
# 13                     12_population_growth_population growth_immigration
# 14                           13_labour_immigration_rt labour_labour party
# 15                                 14_wages_wage_immigration_bank england
#
#                                 CustomName
# 0   -1_immigration_ukip_migration_migrants
# 1                        illegal migration
# 2                      pro-brexit campaign
# 3                         arrivals by boat
# 4                       immigration issues
# 5                           eu immigration
# 6                 tories' migration policy
# 7                        ukip's propaganda
# 8          points based immigration system
# 9                           housing crisis
# 10              cameron's migration policy
# 11                          migrant crisis
# 12                       about home office
# 13                       population growth
# 14       labour's migration responsability
# 15                      workers' low wages

# %% [markdown]
# ###**Dynamic Topic Modeling (DTM)**

# %%
# Set topics over time
topics_over_time = migr_topic_model.topics_over_time(docs=tweet_list, 
                                                timestamps=timestamps, 
                                                global_tuning=True, 
                                                evolution_tuning=True, 
                                                nr_bins=20)
# Out:
# 20it [00:17,  1.17it/s]

# %%
# Visualize topics over time
migr_topic_model.visualize_topics_over_time(topics_over_time, top_n_topics=15, custom_labels=migr_topic_model.set_topic_labels, normalize_frequency=True, width=1350, height=550)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="9fffcc74-d86a-4214-9b9e-a92d2892b598" class="plotly-graph-div" style="height:550px; width:1350px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9fffcc74-d86a-4214-9b9e-a92d2892b598")) {                    Plotly.newPlot(                        "9fffcc74-d86a-4214-9b9e-a92d2892b598",                        [{"hoverinfo":"text","hovertext":["<b>Topic 0</b><br>Words: asylum, issue hofc, asylum electric bills, asylum electric, leaflet asylum","<b>Topic 0</b><br>Words: immigrationbill, immigrationbill make harder, new immigrationbill steps, immigrants announced immigrationbill, amp ensure legal","<b>Topic 0</b><br>Words: seekers syria, asylum seekers syria, uk accepts asylum, seekers syria telegraph, accepts asylum","<b>Topic 0</b><br>Words: vulnerable, refugees, syrian refugees, comes exactly syrian, uk today governments","<b>Topic 0</b><br>Words: asylum, asylum cases, ability offer asylum, offer asylum mep, constrains member states","<b>Topic 0</b><br>Words: syrian, refugees, syrian refugees, syrian refugees syria, refugees uk hope","<b>Topic 0</b><br>Words: syrian refugees, refugees, asylum, just glasgow airport, child asylum seekers","<b>Topic 0</b><br>Words: refugees, syrian refugees, syrian, archbishop, refugee","<b>Topic 0</b><br>Words: refugees, children, vulnerable syrian, vulnerable syrian refugees, syrian refugees","<b>Topic 0</b><br>Words: refugees, refugees resettled uk, resettled uk, refugees resettled, syrian refugees resettled","<b>Topic 0</b><br>Words: refugees, syrian refugees, vulnerable, minister today, asylum","<b>Topic 0</b><br>Words: groups, g6, support, community sponsorship, refugees","<b>Topic 0</b><br>Words: french interior, french interior minister, interior minister, efforts migrant, efforts migrant activity","<b>Topic 0</b><br>Words: work closely european, strengthen police amp, borders crucial work, immigration amp stop, amp exploitation people","<b>Topic 0</b><br>Words: illegal migration, france, asylum, migration, french","<b>Topic 0</b><br>Words: asylum, enhanced agreement, interior minister, french interior, french interior minister","<b>Topic 0</b><br>Words: asylum, new plan immigration, new plan, plan immigration, people smugglers","<b>Topic 0</b><br>Words: illegal migration, asylum, migration, bordersbill, nnewplanforimmigration","<b>Topic 0</b><br>Words: rwanda, migration, migrants, illegal migration, uk rwanda"],"marker":{"color":"#E69F00"},"mode":"lines","name":"illegal migration","x":["2011-12-29T14:37:11.676000","2013-01-26T10:15:54.400000","2013-08-09T09:17:50.600000","2014-02-20T08:19:46.800000","2014-09-03T07:21:43","2015-03-17T06:23:39.200000","2015-09-28T05:25:35.400000","2016-04-10T04:27:31.600000","2016-10-22T03:29:27.800000","2017-05-05T02:31:24","2017-11-16T01:33:20.200000","2018-05-30T00:35:16.400000","2018-12-10T23:37:12.600000","2019-06-23T22:39:08.800000","2020-01-04T21:41:05","2020-07-17T20:43:01.200000","2021-01-28T19:44:57.400000","2021-08-11T18:46:53.600000","2022-02-22T17:48:49.800000"],"y":[0.023047195683407233,0.017285396762555427,0.12099777733788798,0.028808994604259043,0.046094391366814466,0.12099777733788798,0.040332592445962656,0.1325213751795916,0.10371238057533255,0.08066518489192531,0.08642698381277712,0.09218878273362893,0.1901393643881097,0.03457079352511085,0.07490338597107352,0.17285396762555424,0.3802787287762194,0.3802787287762194,0.7432720607898833],"type":"scatter"},{"hoverinfo":"text","hovertext":["<b>Topic 1</b><br>Words: absolutely eu, change absolutely eu, change absolutely, pleased labour admitted, immigration proposals change","<b>Topic 1</b><br>Words: eu simple, control immigration, immigration policy, uncontrolled immigration, speaking british majority","<b>Topic 1</b><br>Words: farage, nigel farage, nigel, uki ...

# %% [markdown]
# ###**Topics per Class**

# %%
# Set topics per class
topics_per_party = migr_topic_model.topics_per_class(tweet_list, classes=tweet_party, global_tuning=True)
# Out:
# 2it [00:01,  1.60it/s]

# %%
# Visualize topics per party
migr_topic_model.visualize_topics_per_class(topics_per_party, top_n_topics=15, custom_labels=migr_topic_model.set_topic_labels, normalize_frequency=True, width=1350, height=550)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="468868f1-61f7-43fd-87e2-af1044eb7000" class="plotly-graph-div" style="height:550px; width:1350px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("468868f1-61f7-43fd-87e2-af1044eb7000")) {                    Plotly.newPlot(                        "468868f1-61f7-43fd-87e2-af1044eb7000",                        [{"hoverinfo":"text","hovertext":["<b>Topic 0</b><br>Words: asylum, refugees, migrants, asylum seekers, seekers","<b>Topic 0</b><br>Words: asylum, rwanda, migration, illegal migration, refugees"],"marker":{"color":"#E69F00"},"name":"illegal migration","orientation":"h","visible":true,"x":[0.31470459447623844,0.9491896639847837],"y":["far-right","right-wing"],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 1</b><br>Words: australian style, ukip, nigel farage, nigel, australian style points","<b>Topic 1</b><br>Words: australian style, australian style points, style points, style points based, points based"],"marker":{"color":"#56B4E9"},"name":"pro-brexit campaign","orientation":"h","visible":"legendonly","x":[0.9936976144757079,0.11209393821829633],"y":["far-right","right-wing"],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 2</b><br>Words: migrants, calais, dover, illegal migrants, migrant","<b>Topic 2</b><br>Words: migrants, smuggling, immigration enforcement, calais, boats"],"marker":{"color":"#009E73"},"name":"arrivals by boat","orientation":"h","visible":"legendonly","x":[0.9611640138638261,0.2759777861589204],"y":["far-right","right-wing"],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 3</b><br>Words: immigration, wales, nhs, ukip, migrants","<b>Topic 3</b><br>Words: immigration, priority matter immigration, health uk, governments priority matter, matter immigration status"],"marker":{"color":"#F0E442"},"name":"immigration issues","orientation":"h","visible":"legendonly","x":[0.9976761801086667,0.06813398303181138],"y":["far-right","right-wing"],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 4</b><br>Words: eu, bulgarian, romania, bulgaria, asylum policy","<b>Topic 4</b><br>Words: eu, asylum, romanian, migration njoint, cooperation vital countries"],"marker":{"color":"#D55E00"},"name":"eu immigration","orientation":"h","visible":"legendonly","x":[0.9998237147691289,0.018776032202237163],"y":["far-right","right-wing"],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 5</b><br>Words: tories, boris, priti patel, boris johnson, tory","<b>Topic 5</b><br>Words: priti patel, ukaid burma, rohingya refugee, rohingya refugee crisis, priti patel calls"],"marker":{"color":"#0072B2"},"name":"tories' migration policy","orientation":"h","visible":"legendonly","x":[0.999955919950609,0.009389257464324967],"y":["far-right","right-wing"],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 6</b><br>Words: ukip, migration spokesman, ukip migration, ukip migration spokesman, ukip immigration","<b>Topic 6</b><br>Words: details weeks announcements, details weeks, weeks announcements, migration spokesman, ukip migration"],"marker":{"color":"#CC79A7"},"name":"ukip's propaganda","orientation":"h","visible":"legendonly","x":[0.9999885535721436,0.004784634227617912],"y":["far-right","right-wing"],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 7</b><br>Words: movement acceptable, saying free movement, saying free, davis saying free, free movement acceptable","<b>Topic 7</b><br>Words: based immigration, points based immigration, immigration, points based, points"],"marker":{"color":"#E69F00"},"name":"points based immigration system","orientation":"h","visible":"legendonly","x":[0.03515413726662778,0.9993819022941326],"y":["far-right","right-wing"],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 8</b><br>Words: housing, housing crisis, immigration, ...

# %%
# Set topics per political actor
topics_per_actor = migr_topic_model.topics_per_class(tweet_list, classes=tweet_username, global_tuning=True)
# Out:
# 12it [00:05,  2.14it/s]

# %%
# Visualize topics per political actor
migr_topic_model.visualize_topics_per_class(topics_per_actor, top_n_topics=15, custom_labels=migr_topic_model.set_topic_labels, normalize_frequency=True, width=1350, height=550)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="51ee8a1a-655d-445d-a791-cb3874e116e5" class="plotly-graph-div" style="height:550px; width:1350px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("51ee8a1a-655d-445d-a791-cb3874e116e5")) {                    Plotly.newPlot(                        "51ee8a1a-655d-445d-a791-cb3874e116e5",                        [{"hoverinfo":"text","hovertext":["<b>Topic 0</b><br>Words: community sponsorship, refugees, minister today, syrian refugees, refugee","<b>Topic 0</b><br>Words: asylum, accepts asylum seekers, accepts asylum, seekers syria, seekers syria telegraph","<b>Topic 0</b><br>Words: rwanda, asylum, refugees, migration, partnership","<b>Topic 0</b><br>Words: rwanda, rwanda migrant, rwanda migrant plan, french police, asylum","<b>Topic 0</b><br>Words: agreement, migration, agreement france, returns agreement, libya","<b>Topic 0</b><br>Words: refugees, asylum, syrian, children, syrian refugees","<b>Topic 0</b><br>Words: crisis, migration, illegal migration, partnership, france","<b>Topic 0</b><br>Words: asylum, illegal migration, rwanda, migration, partnership","<b>Topic 0</b><br>Words: asylum, rwanda, refugees, syrian refugees, migrants","<b>Topic 0</b><br>Words: asylum, children, cheat way benefitsbritain, office wonder fraudsters, entering uk adults","<b>Topic 0</b><br>Words: rwanda, asylum, refugees, migrants, migrants rwanda","<b>Topic 0</b><br>Words: syrian refugees, refugees, refugees taking, statement syria refugees, syrian refugees taking"],"marker":{"color":"#E69F00"},"name":"illegal migration","orientation":"h","visible":true,"x":[0.026821695242516,0.107286780970064,0.8736209307562354,0.034485036740377714,0.026821695242516,0.09196009797434057,0.061306731982893714,0.429147123880256,0.13794014696151086,0.022990024493585143,0.080465085727548,0.015326682995723429],"y":["@AmberRuddUK","@RobinTilbrook","@ukhomeoffice","@TiceRichard","@BorisJohnson","@NickGriffinBU","@sajidjavid","@pritipatel","@UKIP","@NeilUKIP","@Nigel_Farage","@David_Cameron"],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 1</b><br>Words: soubry gt, comment soubry, comment soubry gt, soubry gt gt, revealing comment soubry","<b>Topic 1</b><br>Words: leaving nigel, nigel farage highlight, highlight obscenity happening, farage highlight obscenity, obscenity happening","<b>Topic 1</b><br>Words: australian style, style points based, australian style points, style points, points based","<b>Topic 1</b><br>Words: farage, ukip, australian, australian style, points","<b>Topic 1</b><br>Words: farage, australian, australian style, australian style points, points","<b>Topic 1</b><br>Words: australian style, australian style points, style points based, points based, points based immigration","<b>Topic 1</b><br>Words: farage, australian style, ukip, nigel farage, nigel","<b>Topic 1</b><br>Words: australian, australian style, australian style points, ukip, nigel farage","<b>Topic 1</b><br>Words: farage, nigel farage, australian style, nigel, australian style points"],"marker":{"color":"#56B4E9"},"name":"pro-brexit campaign","orientation":"h","visible":"legendonly","x":[0.0042682458683214585,0.008536491736642917,0.10670614670803646,0.08109667149810772,0.012804737604964376,0.03841421281489313,0.9176728616891137,0.017072983473285834,0.3713373905439669],"y":["@RobinTilbrook","@TiceRichard","@BorisJohnson","@NickGriffinBU","@sajidjavid","@pritipatel","@UKIP","@NeilUKIP","@Nigel_Farage"],"type":"bar"},{"hoverinfo":"text","hovertext":["<b>Topic 2</b><br>Words: calais, migrants, channel, monthly total recorded, migrants kent coast","<b>Topic 2</b><br>Words: migrants, channel, smuggling, immigration enforcement, calais","<b>Topic 2</b><br>Words: migrants, channel, boats, illegal migrants, calais","<b>Topic 2</b><br>Words: calais, dover, migra ...
